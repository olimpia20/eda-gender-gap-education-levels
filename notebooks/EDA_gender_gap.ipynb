# %%
# If running in Google Colab, install required packages from `requirements.txt`
# (Colab ignores local files unless you upload or point to raw GitHub URL)
try:
    # In Colab this will work if the file is present in the working dir (or you uploaded it)
    get_ipython()
    IN_IPYTHON = True
except NameError:
    IN_IPYTHON = False

if IN_IPYTHON:
    import sys
    import subprocess
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-r', 'requirements.txt'], check=False)

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

print('pandas', pd.__version__)
print('seaborn', sns.__version__)
print('matplotlib', plt.__version__)

# %%
# Load your dataset here. Examples:
# 1) From a local file (when running locally):
# df = pd.read_csv('data/your_file.csv')
# 2) From GitHub raw URL (works in Colab):
# df = pd.read_csv('https://raw.githubusercontent.com/USERNAME/REPO/BRANCH/path/to/file.csv')
# 3) Mount Google Drive in Colab and use file from Drive.

# Placeholder example dataset
df = pd.DataFrame({
    'education_level': ['Primary', 'Primary', 'Secondary', 'Secondary', 'Tertiary', 'Tertiary'],
    'sex': ['male','female','male','female','male','female'],
    'count': [50, 60, 40, 50, 30, 45]
})

df.head()

# %% [markdown]
# ## Quick next steps
# - Replace the placeholder `df` with your dataset load line.
# - Use `df.groupby(['education_level','sex'])['count'].sum().unstack()` to reshape counts by sex.
# - Plot with `seaborn.barplot` or `sns.catplot(kind='bar')` to compare male/female by education level.
